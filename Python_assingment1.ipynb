# %%
# student_result.py

name = input("Enter student name: ")
student_class = input("Enter class: ")

mark1 = float(input("Enter marks of Subject 1: "))
mark2 = float(input("Enter marks of Subject 2: "))
mark3 = float(input("Enter marks of Subject 3: "))
mark4 = float(input("Enter marks of Subject 4: "))
mark5 = float(input("Enter marks of Subject 5: "))

total = mark1 + mark2 + mark3 + mark4 + mark5
percentage = total / 5

print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# ----- RESULT -----
# Student Name : Ram
# Class : 12
# Total Marks : 456.0
# Percentage : 91.2 %

# %%
# string_methods.py

str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

new_string = str1 + str2

print("\nConcatenated String:", new_string)

print("lower():", new_string.lower())
print("upper():", new_string.upper())
print("title():", new_string.title())
print("swapcase():", new_string.swapcase())
print("capitalize():", new_string.capitalize())
print("casefold():", new_string.casefold())

print("center():", new_string.center(50, '*'))

print("count('a'):", new_string.count('a'))

print("endswith('a'):", new_string.endswith('a'))

print("find('a'):", new_string.find('a'))

print("isalnum():", new_string.isalnum())

print("isdigit():", new_string.isdigit())

print("isnumeric():", new_string.isnumeric())

print("isspace():", new_string.isspace())

print("replace():", new_string.replace('a', '@'))
# Out:
# Concatenated String: HelloGood Morning
# lower(): hellogood morning
# upper(): HELLOGOOD MORNING
# title(): Hellogood Morning
# swapcase(): hELLOgOOD mORNING
# capitalize(): Hellogood morning
# casefold(): hellogood morning
# center(): ****************HelloGood Morning*****************
# count('a'): 0
# endswith('a'): False
# find('a'): -1
# isalnum(): False
# isdigit(): False
# isnumeric(): False
# isspace(): False
# replace(): HelloGood Morning

# %%
# assignment_operators.py

x = 10

print("Initial value:", x)

x += 5
print("After += 5 :", x)

x -= 3
print("After -= 3 :", x)

x *= 2
print("After *= 2 :", x)

x /= 4
print("After /= 4 :", x)

x %= 3
print("After %= 3 :", x)

x **= 2
print("After **= 2 :", x)

x //= 2
print("After //= 2 :", x)
# Out:
# Initial value: 10
# After += 5 : 15
# After -= 3 : 12
# After *= 2 : 24
# After /= 4 : 6.0
# After %= 3 : 0.0
# After **= 2 : 0.0
# After //= 2 : 0.0

# %%
# student_grade.py

name = input("Enter student name: ")
student_class = input("Enter class: ")

mark1 = float(input("Enter marks of Subject 1: "))
mark2 = float(input("Enter marks of Subject 2: "))
mark3 = float(input("Enter marks of Subject 3: "))
mark4 = float(input("Enter marks of Subject 4: "))
mark5 = float(input("Enter marks of Subject 5: "))

total = mark1 + mark2 + mark3 + mark4 + mark5
percentage = total / 5

# Grade calculation
if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'Fail'

print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
print("Grade :", grade)
# Out:
# ----- RESULT -----
# Student Name : Shyam
# Class : 12
# Total Marks : 452.0
# Percentage : 90.4 %
# Grade : A
